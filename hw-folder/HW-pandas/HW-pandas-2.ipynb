# %% [markdown]
# # Отбор необходимых данных

# %%
import pandas as pd

# %% [markdown]
# ## а) Сохраните в файл train_part.csv следующую часть из файла train.csv
# ### - Строки, где matches больше чем среднее

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Serfentum/bf_course/master/14.pandas/train.csv')
df.query('matches > matches.mean()')
# Out:
#     pos  reads_all  matches  mismatches  deletions  insertions      A      C  \
# 1   280       8045     7995          48         19           9    NaN   16.0
# 2   281       8045     7983          50         16           5    NaN   24.0
# 3   282       8049     7510         505         33          65  105.0   11.0
# 4   283       8042     7786         155        115          62   46.0    NaN
# 5   284       8048     7094         104        864         241   24.0   57.0
# 17  296       8039     4870        1883       1308          50    NaN  657.0
# 19  298       8047     5939         769       1345          12  124.0    NaN
# 20  299       8043     6284         728       1053          60  210.0  197.0
# 21  300       8049     6722         862        468          64   81.0  142.0
# 22  301       8050     6135        1395        516          51  100.0  483.0
# 25  304       8051     5310        1492       1248          63  204.0  361.0
# ...

# %% [markdown]
# ### - Колонки pos, reads_all, mismatches, deletions, insertions

# %%
df_selected = df.query('matches > matches.mean()').loc[: ,['pos', 'reads_all', 'mismatches', 'deletions', 'insertions']].set_index('pos')

# %%
df_selected
# Out:
#      reads_all  mismatches  deletions  insertions
# pos
# 280       8045          48         19           9
# 281       8045          50         16           5
# 282       8049         505         33          65
# 283       8042         155        115          62
# 284       8048         104        864         241
# 296       8039        1883       1308          50
# 298       8047         769       1345          12
# 299       8043         728       1053          60
# 300       8049         862        468          64
# 301       8050        1395        516          51
# 304       8051        1492       1248          63
# 305       8048        1054       1641          36
# 311       8051        1479       1558          90
# 312       8051        1766       1556         159
# 313       8054        1337       1687          66
# 320       8052         584       1194          18
# 321       8059         748        839          53
# 322       8053         451        315         243
# ...
